# %%
from google.cloud import vision

# %%
def detect_web(path):
    """Detects web annotations given an image."""

    client = vision.ImageAnnotatorClient()

    with open(path, "rb") as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.web_detection(image=image)
    annotations = response.web_detection
    print("annotations: ", annotations)

    if annotations.best_guess_labels:
        for label in annotations.best_guess_labels:
            print(f"\nBest guess label: {label.label}")

    if annotations.pages_with_matching_images:
        print(
            "\n{} Pages with matching images found:".format(
                len(annotations.pages_with_matching_images)
            )
        )

        for page in annotations.pages_with_matching_images:
            print(f"\n\tPage url   : {page.url}")

            if page.full_matching_images:
                print(
                    "\t{} Full Matches found: ".format(len(page.full_matching_images))
                )

                for image in page.full_matching_images:
                    print(f"\t\tImage url  : {image.url}")

            if page.partial_matching_images:
                print(
                    "\t{} Partial Matches found: ".format(
                        len(page.partial_matching_images)
                    )
                )

                for image in page.partial_matching_images:
                    print(f"\t\tImage url  : {image.url}")

    if annotations.web_entities:
        print("\n{} Web entities found: ".format(len(annotations.web_entities)))

        for entity in annotations.web_entities:
            print(f"\n\tScore      : {entity.score}")
            print(f"\tDescription: {entity.description}")

    if annotations.visually_similar_images:
        print(
            "\n{} visually similar images found:\n".format(
                len(annotations.visually_similar_images)
            )
        )

        for image in annotations.visually_similar_images:
            print(f"\tImage url    : {image.url}")

    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )

# %%
detect_web("/Users/keonhongkoo/Downloads/KakaoTalk_Photo_2023-12-22-00-24-25.png")
# Out:
# annotations:  web_entities {
#   entity_id: "/m/09t49"
#   score: 0.534035861
#   description: "Leaf"
# }
# web_entities {
#   entity_id: "/m/02yhp1"
#   score: 0.515917778
#   description: "San Pedro cactus"
# }
# web_entities {
#   entity_id: "/m/05s2s"
#   score: 0.4164
#   description: "Plant"
# }
# web_entities {
#   entity_id: "/m/01ttd6"
#   score: 0.39707461
#   description: "Plant stem"
# }
# web_entities {
#   entity_id: "/m/025_v"
#   score: 0.3961
#   description: "Cactus"
# }
# web_entities {
#   entity_id: "/m/09qck"
#   score: 0.37741515
#   description: "Banana"
# }
# web_entities {
#   entity_id: "/m/0fm3zh"
#   score: 0.318234593
#   description: "Flowerpot"
# }
# web_entities {
#   entity_id: "/m/06121f"
#   score: 0.3126
#   description: "Echinocereus"
# }
# visually_similar_images {
#   url: "https://preview.redd.it/48uhcityomm91.jpg?width=3024&format=pjpg&auto=webp&s=2f18be8647032cfeea458de4fb049d01f75c6da9"
# }
# visually_similar_images {
#   url: "https://d2j6dbq0eux0bg.cloudfront.net/images/795111/3596168877.jpg"
# }
# visually_similar_images {
#   url: "https://preview.redd.it/6c4cvxx5ffz51.jpg?width=3024&format=pjpg&auto=webp&s=bd472f2eb635f4eb717cb0db40be51136a71aa40"
# }
# visually_similar_images {
#   url: "https://www.torontomastergardeners.ca/wp-content/uploads/formidable/2/WhatsApp-Image-2023-06-20-at-11.45.36-1-768x1024.jpeg"
# }
# visually_similar_images {
#   url: "https://preview.redd.it/stem-with-no-leaf-emerging-from-m-deliciosa-bought-and-v0-8uss84dblc3a1.jpg?width=640&crop=smart&auto=webp&s=679e495dbb06a751fe1fdbb29424884ccc1ab6ce"
# }
# visually_similar_images {
#   url: "https://cdn.shortpixel.ai/spai/w_924+q_glossy+ret_img+to_webp/planethouseplant.com/wp-content/uploads/2023/09/monstera-new-leaf-3.jpg"
# }
# visually_similar_images {
#   url: "https://www.meadowsfarms.com/wp-content/uploads/2019/01/fiddle-leaf-fig.jpg"
# }
# visually_similar_images {
#   url: "https://www.bananatreesforsale.com/wp-content/uploads/2017/07/gf4669.jpg"
# }
# visually_similar_images {
#   url: "https://cdn2.hubspot.net/hubfs/52259/28-when-how-cut-leaf.jpg"
# }
# visually_similar_images {
#   url: "https://s3g2u3k4.rocketcdn.me/wp-content/uploads/sites/4/2022/07/Indoor-Banana-tree.jpg"
# }
# best_guess_labels {
#   label: "leaf"
# }
#
#
# Best guess label: leaf
#
# 8 Web entities found:
#
# 	Score      : 0.534035861492157
# 	Description: Leaf
#
# 	Score      : 0.5159177780151367
# 	Description: San Pedro cactus
#
# 	Score      : 0.4163999855518341
# 	Description: Plant
#
# 	Score      : 0.3970746099948883
# 	Description: Plant stem
#
# 	Score      : 0.3961000144481659
# 	Description: Cactus
#
# 	Score      : 0.37741515040397644
# 	Description: Banana
#
# 	Score      : 0.3182345926761627
# 	Description: Flowerpot
#
# 	Score      : 0.3125999867916107
# 	Description: Echinocereus
#
# 10 visually similar images found:
#
# 	Image url    : https://preview.redd.it/48uhcityomm91.jpg?width=3024&format=pjpg&auto=webp&s=2f18be8647032cfeea458de4fb049d01f75c6da9
# 	Image url    : https://d2j6dbq0eux0bg.cloudfront.net/images/795111/3596168877.jpg
# 	Image url    : https://preview.redd.it/6c4cvxx5ffz51.jpg?width=3024&format=pjpg&auto=webp&s=bd472f2eb635f4eb717cb0db40be51136a71aa40
# 	Image url    : https://www.torontomastergardeners.ca/wp-content/uploads/formidable/2/WhatsApp-Image-2023-06-20-at-11.45.36-1-768x1024.jpeg
# 	Image url    : https://preview.redd.it/stem-with-no-leaf-emerging-from-m-deliciosa-bought-and-v0-8uss84dblc3a1.jpg?width=640&crop=smart&auto=webp&s=679e495dbb06a751fe1fdbb29424884ccc1ab6ce
# 	Image url    : https://cdn.shortpixel.ai/spai/w_924+q_glossy+ret_img+to_webp/planethouseplant.com/wp-content/uploads/2023/09/monstera-new-leaf-3.jpg
# 	Image url    : https://www.meadowsfarms.com/wp-content/uploads/2019/01/fiddle-leaf-fig.jpg
# 	Image url    : https://www.bananatreesforsale.com/wp-content/uploads/2017/07/gf4669.jpg
# 	Image url    : https://cdn2.hubspot.net/hubfs/52259/28-when-how-cut-leaf.jpg
# 	Image url    : https://s3g2u3k4.rocketcdn.me/wp-content/uploads/sites/4/2022/07/Indoor-Banana-tree.jpg

# %%
detect_web("/Users/keonhongkoo/Downloads/R720x0.jpeg")
# Out:
# annotations:  web_entities {
#   entity_id: "/g/11bzt28nj_"
#   score: 1.06905007
#   description: "Saitama"
# }
# web_entities {
#   entity_id: "/m/011q2fjr"
#   score: 0.96
#   description: "ONE"
# }
# web_entities {
#   entity_id: "/g/11bzrlb5v2"
#   score: 0.7644
#   description: "One Punch Man"
# }
# web_entities {
#   entity_id: "/m/0ndskrg"
#   score: 0.7214
#   description: "One-Punch Man"
# }
# web_entities {
#   entity_id: "/g/11khz3dd94"
#   score: 0.69255
#   description: "One Punch Man : Hero Perfection"
# }
# web_entities {
#   entity_id: "/m/04spm"
#   score: 0.5868
#   description: "Manga"
# }
# web_entities {
#   entity_id: "/g/11h7vcbz_6"
#   score: 0.5529
#   description: "Japanese Anime T Shirt"
# }
# web_entities {
#   entity_id: "/m/0jxy"
#   score: 0.5096
#   description: "Anime"
# }
# web_entities {
#   entity_id: "/g/11g6qmj1jx"
#   score: 0.3806
#   description: "One Punch Man"
# }
# web_entities {
#   entity_id: "/g/11pc55dy8w"
#   score: 0.3442
#   description: "realistic"
# }
# full_matching_images {
#   url: "https://cdn.hk01.com/di/media/images/2590768/org/e630cf9075583b08578825beaf13cdc4.png/hVFU2W10YwLO49hspoxiQBZ6nkiJFydk4rAtkOKwLZA?v=w1920"
# }
# full_matching_images {
#   url: "http://upload2.inven.co.kr/upload/2017/03/08/bbs/i15713445725.png"
# }
# full_matching_images {
#   url: "https://d2u3dcdbebyaiu.cloudfront.net/uploads/atch_img/778/a3b8e9012f1930a4f15e3d8cda43a5ae_res.jpeg"
# }
# full_matching_images {
#   url: "https://d2u3dcdbebyaiu.cloudfront.net/uploads/atch_img/98/5eff5497272c110cb6906c90228010b8_res.jpeg"
# }
# full_matching_images {
#   url: "https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1596157403893376"
# }
# full_matching_images {
#   url: "https://img1.daumcdn.net/thumb/R1280x0/?fname=http://t1.daumcdn.net/brunch/service/user/UTz/image/Wm5_DDSzR5f5QkakRWK4aErOeXg.jpg"
# }
# full_matching_images {
#   url: "https://cdn.orangenews.hk/pic/0/10/19/83/10198380_849242.jpg?x-oss-process=style/w960"
# }
# full_matching_images {
#   url: "http://1.bp.blogspot.com/-Y1Ua4OEOS_I/Vbbtjfa2TkI/AAAAAAAABik/-SKuDI3yZe8/s1600/007.jpg"
# }
# full_matching_images {
#   url: "https://i.imgur.com/UziLTUd.png"
# }
# full_matching_images {
#   url: "https://1.bp.blogspot.com/-rH6M0ox-pAU/YQiSQypJLtI/AAAAAAAAZgY/YcUjbIh5bgkFx_hruZuoPUt9s5tF2KO7wCLcBGAsYHQ/s967/One-Punch-Man-Workout.jpg"
# }
# partial_matching_images {
#   url: "https://mblogthumb-phinf.pstatic.net/20151117_215/rlawlsdn117_1447730259889BwVAS_JPEG/c312dd265a6f11dfd301b84cb0059ffe.jpg?type=w420"
# }
# partial_matching_images {
#   url: "https://pbs.twimg.com/media/Dy5f8ThV4AAQpeQ.jpg"
# }
# partial_matching_images {
#   url: "https://mblogthumb-phinf.pstatic.net/MjAyMTA1MTZfMTA2/MDAxNjIxMTcxOTY5NjYx.10DS3OdvB7z34xBECZK4n3UN9nikmL9D5TA6KCIi9ckg.UduQOaIM-7Rb9JaOwzkPMpMCCwoQTJuPE7PSfX-gO_Ig.JPEG.usuu0919/SE-827ee3ea-2c17-4c97-9f9a-615324b137e1.jpg?type=w800"
# }
# partial_matching_images {
#   url: "https://cdn.mania.kr/nbamania/g2/data/cheditor5/2010/f21d581ef07f41e881fdc8a87c275f0b.jpg"
# }
# partial_matching_images {
#   url: "https://mblogthumb-phinf.pstatic.net/20160502_30/enomme_1462157478684DXqwc_JPEG/%BB%E7%C0%CC%C5%B8%B8%B6_%C8%C6%B7%C3%B9%FD.jpg?type=w420"
# }
# partial_matching_images {
#   url: "https://image.yes24.com/images/chyes24/8/e/5/3/8e5340f2b443f851b9018ca15994498e.jpg"
# }
# partial_matching_images {
#   url: "https://dcimg4.dcinside.co.kr/viewimage.php?id=2fbcc323e7d334aa51b1d3a24780&no=24b0d769e1d32ca73fea8efa11d028317044ef0bb41aaa70c68a373cd4e68bbafe64e2cc76ccf08cd70d5dc068f3c141adb52653feff7652305e4d24e9fffdfa7b552ac35997498d85f802279661435eff1154b33b60b15569f4194338112a926dda08ad771a625a2cdc97961f783d"
# }
# partial_matching_images {
#   url: "https://img.ppomppu.co.kr/zboard/data3/comment/32/help_4630332"
# }
# partial_matching_images {
#   url: "https://pm1.aminoapps.com/6192/f5eedca996f93da2d476aef6c2de61842002b8fc_hq.jpg"
# }
# partial_matching_images {
#   url: "https://mblogthumb-phinf.pstatic.net/20151008_188/zzyq009_1444269016421wqIEp_JPEG/R750x0.jpeg?type=w420"
# }
# pages_with_matching_images {
#   url: "https://roamstrong.com/one-punch-man-workout/"
#   page_title: "The <b>One Punch Man Workout</b> - Roam Strong"
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.quora.com/What-would-happen-if-you-did-One-Punch-Mans-workout-and-did-a-hundred-push-ups-a-hundred-sit-ups-and-ran-10km-every-day-for-a-year"
#   page_title: "What would happen if you did <b>One Punch Man&#39;s workout</b> ... - Quora"
#   full_matching_images {
#     url: "https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.eastanglianseaschool.com/?e=daily-workout-one-punch-man-vs-bruce-lee-gaming-cc-4Y928qfP"
#   page_title: "Daily <b>Workout</b>: <b>One Punch Man</b> vs Bruce Lee Gaming One punch ..."
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.quora.com/What-would-I-need-to-add-to-the-One-Punch-Man-workout-to-make-it-even-more-balanced"
#   page_title: "What would I need to add to the <b>One Punch Man workout</b> to make it ..."
#   full_matching_images {
#     url: "https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.quora.com/What-are-the-flaws-of-the-One-Punch-Man-workout"
#   page_title: "What are the flaws of the <b>One</b>-<b>Punch Man workout</b>? - Quora"
#   full_matching_images {
#     url: "https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.quora.com/Is-the-One-Punch-Man-workout-good-for-beginners-to-training"
#   page_title: "Is the <b>One Punch Man workout</b> good for beginners to training? - Quora"
#   full_matching_images {
#     url: "https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.bridgepartnersllc.com/team?en=5.5.2048087.3.29.39.one+punch+man+workout"
#   page_title: "<b>One Punch Man Workout</b> - Bridge Partners"
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.bridgepartnersllc.com/team?en=5.6.2628916.1.21.38.one+punch+man+workout+routine"
#   page_title: "<b>One Punch Man Workout</b> Routine - Bridge Partners"
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.hidymec.com/?o=one-punch-man-workout-how-to-become-as-strong-zz-dkV8NPHR"
#   page_title: "<b>One</b>-<b>Punch Man Workout</b>: How to Become as Strong as Saitama"
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.disalia.com/?u=daily-workout-one-punch-man-vs-bruce-lee-gaming-nn-QA2P4Ip"
#   page_title: "Daily <b>Workout</b>: <b>One Punch Man</b> Vs Bruce Lee Gaming One ... - Disalia"
#   partial_matching_images {
#     url: "https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg"
#   }
# }
# visually_similar_images {
#   url: "https://i.pinimg.com/474x/aa/36/4c/aa364cad34979a5786e613543ab5baa9.jpg"
# }
# visually_similar_images {
#   url: "https://qph.cf2.quoracdn.net/main-qimg-2485633a6ce79a8d5459b3fc6f102ae5-lq"
# }
# visually_similar_images {
#   url: "https://otakukart.com/wp-content/uploads/2023/03/One-Punch-Man-Workout-e1678795469537.jpg"
# }
# visually_similar_images {
#   url: "https://i0.wp.com/quotetheanime.com/wp-content/uploads/2022/11/training.jpeg"
# }
# visually_similar_images {
#   url: "https://img-9gag-fun.9cache.com/photo/aAxGjn0_460s.jpg"
# }
# visually_similar_images {
#   url: "https://dietplanworkout.com/wp-content/uploads/2019/02/saitamas-best-workout-routine-e1555098451807.jpg"
# }
# visually_similar_images {
#   url: "https://fictionhorizon.com/wp-content/uploads/2022/08/one-punch-man-.jpg"
# }
# visually_similar_images {
#   url: "https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=708381433301619"
# }
# visually_similar_images {
#   url: "https://qph.cf2.quoracdn.net/main-qimg-e60cf4547a065f822d22209e63e2ac52-pjlq"
# }
# visually_similar_images {
#   url: "https://i.redd.it/fbt3o9jls1la1.jpg"
# }
# best_guess_labels {
#   label: "one punch man workout"
#   language_code: "en"
# }
#
#
# Best guess label: one punch man workout
#
# 10 Pages with matching images found:
#
# 	Page url   : https://roamstrong.com/one-punch-man-workout/
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 	Page url   : https://www.quora.com/What-would-happen-if-you-did-One-Punch-Mans-workout-and-did-a-hundred-push-ups-a-hundred-sit-ups-and-ran-10km-every-day-for-a-year
# 	1 Full Matches found:
# 		Image url  : https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq
#
# 	Page url   : https://www.eastanglianseaschool.com/?e=daily-workout-one-punch-man-vs-bruce-lee-gaming-cc-4Y928qfP
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 	Page url   : https://www.quora.com/What-would-I-need-to-add-to-the-One-Punch-Man-workout-to-make-it-even-more-balanced
# 	1 Full Matches found:
# 		Image url  : https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq
#
# 	Page url   : https://www.quora.com/What-are-the-flaws-of-the-One-Punch-Man-workout
# 	1 Full Matches found:
# 		Image url  : https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq
#
# 	Page url   : https://www.quora.com/Is-the-One-Punch-Man-workout-good-for-beginners-to-training
# 	1 Full Matches found:
# 		Image url  : https://qph.cf2.quoracdn.net/main-qimg-b100bbd9b878d99022b92abbb0028233-pjlq
#
# 	Page url   : https://www.bridgepartnersllc.com/team?en=5.5.2048087.3.29.39.one+punch+man+workout
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 	Page url   : https://www.bridgepartnersllc.com/team?en=5.6.2628916.1.21.38.one+punch+man+workout+routine
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 	Page url   : https://www.hidymec.com/?o=one-punch-man-workout-how-to-become-as-strong-zz-dkV8NPHR
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 	Page url   : https://www.disalia.com/?u=daily-workout-one-punch-man-vs-bruce-lee-gaming-nn-QA2P4Ip
# 	1 Partial Matches found:
# 		Image url  : https://roamstrong.com/wp-content/uploads/2015/11/One-Punch-Man-Workout.jpg
#
# 10 Web entities found:
#
# 	Score      : 1.0690500736236572
# 	Description: Saitama
#
# 	Score      : 0.9599999785423279
# 	Description: ONE
#
# 	Score      : 0.7644000053405762
# 	Description: One Punch Man
#
# 	Score      : 0.7214000225067139
# 	Description: One-Punch Man
#
# 	Score      : 0.692550003528595
# 	Description: One Punch Man : Hero Perfection
#
# 	Score      : 0.5867999792098999
# 	Description: Manga
#
# 	Score      : 0.5529000163078308
# 	Description: Japanese Anime T Shirt
#
# 	Score      : 0.5095999836921692
# 	Description: Anime
#
# 	Score      : 0.3806000053882599
# 	Description: One Punch Man
#
# 	Score      : 0.3441999852657318
# 	Description: realistic
#
# 10 visually similar images found:
#
# 	Image url    : https://i.pinimg.com/474x/aa/36/4c/aa364cad34979a5786e613543ab5baa9.jpg
# 	Image url    : https://qph.cf2.quoracdn.net/main-qimg-2485633a6ce79a8d5459b3fc6f102ae5-lq
# 	Image url    : https://otakukart.com/wp-content/uploads/2023/03/One-Punch-Man-Workout-e1678795469537.jpg
# 	Image url    : https://i0.wp.com/quotetheanime.com/wp-content/uploads/2022/11/training.jpeg
# 	Image url    : https://img-9gag-fun.9cache.com/photo/aAxGjn0_460s.jpg
# 	Image url    : https://dietplanworkout.com/wp-content/uploads/2019/02/saitamas-best-workout-routine-e1555098451807.jpg
# 	Image url    : https://fictionhorizon.com/wp-content/uploads/2022/08/one-punch-man-.jpg
# 	Image url    : https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=708381433301619
# 	Image url    : https://qph.cf2.quoracdn.net/main-qimg-e60cf4547a065f822d22209e63e2ac52-pjlq
# 	Image url    : https://i.redd.it/fbt3o9jls1la1.jpg
